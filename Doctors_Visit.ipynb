# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\allab\\Desktop\\Revature\\Project 0'

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\allab\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\allab\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Data Reading or Wrangling

import pandas as pd
df = pd.read_excel('DoctorVisits.xlsx')

# %%
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 0        yes       no        no       no       no
# 1        yes       no        no       no       no
# 2         no       no        no       no       no
# 3         no       no        no       no       no
# 4         no       no        no      yes       no
# ...      ...      ...       ...      ...      ...
# 5185      no       no        no       no       no
# 5186      no       no        no       no       no
# 5187      no       no       yes       no       no
# 5188      no       no        no       no       no
# 5189      no       no       yes       no       no
#
# [5190 rows x 13 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %%
df['reduced'].unique()
# Out:
# array([ 4,  2,  0,  5,  1, 13,  7,  3, 14,  6,  8,  9, 10, 12, 11],
#       dtype=int64)

# %%
df.tail()
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 5185      no       no        no       no       no
# 5186      no       no        no       no       no
# 5187      no       no       yes       no       no
# 5188      no       no        no       no       no
# 5189      no       no       yes       no       no

# %%
df1 = df[df['income']>=0.20]

# %%
df1
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# 5              6       1  female  0.19    0.35        5        1       9
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 0        yes       no        no       no       no
# 1        yes       no        no       no       no
# 2         no       no        no       no       no
# 4         no       no        no      yes       no
# 5         no       no        no      yes       no
# ...      ...      ...       ...      ...      ...
# 5185      no       no        no       no       no
# 5186      no       no        no       no       no
# 5187      no       no       yes       no       no
# 5188      no       no        no       no       no
# 5189      no       no       yes       no       no
#
# [4747 rows x 13 columns]

# %%
df.loc[0:5,'visits':'health']
# Out:
#    visits  gender   age  income  illness  reduced  health
# 0       1  female  0.19    0.55        1        4       1
# 1       1  female  0.19    0.45        1        2       1
# 2       1    male  0.19    0.90        3        0       0
# 3       1    male  0.19    0.15        1        0       0
# 4       1    male  0.19    0.45        2        5       1
# 5       1  female  0.19    0.35        5        1       9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Exploring the unique values of each column
df.nunique()
# Out:
# Unnamed: 0    5190
# visits          10
# gender           2
# age             12
# income          14
# illness          6
# reduced         15
# health          13
# private          2
# freepoor         2
# freerepat        2
# nchronic         2
# lchronic         2
# dtype: int64

# %%
df['income'].value_counts()
# Out:
# income
# 0.25    1195
# 0.90     589
# 0.55     467
# 0.35     462
# 0.65     455
# 0.75     441
# 0.45     400
# 1.10     361
# 0.15     249
# 1.50     215
# 1.30     162
# 0.06      80
# 0.00      79
# 0.01      35
# Name: count, dtype: int64

# %%
df['age'].value_counts()
# Out:
# age
# 0.22    1213
# 0.72     822
# 0.19     752
# 0.27     523
# 0.62     316
# 0.67     315
# 0.32     301
# 0.57     273
# 0.52     222
# 0.47     181
# 0.37     146
# 0.42     126
# Name: count, dtype: int64

# %%
df['age'].describe()
# Out:
# count    5190.000000
# mean        0.406385
# std         0.204782
# min         0.190000
# 25%         0.220000
# 50%         0.320000
# 75%         0.620000
# max         0.720000
# Name: age, dtype: float64

# %%
df['reduced'].value_counts()
# Out:
# reduced
# 0     4454
# 14     188
# 1      177
# 2      108
# 3       74
# 4       45
# 5       40
# 7       38
# 6       17
# 8       17
# 10      12
# 9        7
# 12       6
# 13       5
# 11       2
# Name: count, dtype: int64

# %%
# Data Cleaning
df.drop(['Unnamed: 0'], axis = 1, inplace = True)
df.columns
# Out:
# Index(['visits', 'gender', 'age', 'income', 'illness', 'reduced', 'health',
#        'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df['gender'] = df['gender'].astype('category')
df['gender'].dtypes
# Out:
# CategoricalDtype(categories=['female', 'male'], ordered=False, categories_dtype=object)

# %%
df['age'] = df['age'] * 100
df['income']= df['income'] * 100

# %%
cols1 = ['age','income']
df[cols1] = df[cols1].astype('int')
df[cols1].dtypes
# Out:
# age       int32
# income    int32
# dtype: object

# %%
df.head()
# Out:
#    visits  gender  age  income  illness  reduced  health private freepoor  \
# 0       1  female   19      55        1        4       1     yes       no
# 1       1  female   19      45        1        2       1     yes       no
# 2       1    male   19      90        3        0       0      no       no
# 3       1    male   19      15        1        0       0      no       no
# 4       1    male   19      45        2        5       1      no       no
#
#   freerepat nchronic lchronic
# 0        no       no       no
# 1        no       no       no
# 2        no       no       no
# 3        no       no       no
# 4        no      yes       no

# %%
df.head()
# Out:
#    visits  gender  age  income  illness  reduced  health private freepoor  \
# 0       1  female   19      55        1        4       1     yes       no
# 1       1  female   19      45        1        2       1     yes       no
# 2       1    male   19      90        3        0       0      no       no
# 3       1    male   19      15        1        0       0      no       no
# 4       1    male   19      45        2        5       1      no       no
#
#   freerepat nchronic lchronic
# 0        no       no       no
# 1        no       no       no
# 2        no       no       no
# 3        no       no       no
# 4        no      yes       no

# %%
df.tail()
# Out:
#       visits  gender  age  income  illness  reduced  health private freepoor  \
# 5185       0  female   22      55        0        0       0      no       no
# 5186       0    male   27     130        0        0       1      no       no
# 5187       0  female   37      25        1        0       1      no       no
# 5188       0  female   52      65        0        0       0      no       no
# 5189       0    male   72      25        0        0       0      no       no
#
#      freerepat nchronic lchronic
# 5185        no       no       no
# 5186        no       no       no
# 5187       yes       no       no
# 5188        no       no       no
# 5189       yes       no       no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   visits     5190 non-null   int64
#  1   gender     5190 non-null   category
#  2   age        5190 non-null   int32
#  3   income     5190 non-null   int32
#  4   illness    5190 non-null   int64
#  5   reduced    5190 non-null   int64
#  6   health     5190 non-null   int64
#  7   private    5190 non-null   object
#  8   freepoor   5190 non-null   object
#  9   freerepat  5190 non-null   object
#  10  nchronic   5190 non-null   object
#  11  lchronic   5190 non-null   object
# dtypes: category(1), int32(2), int64(4), object(5)
# memory usage: 410.8+ KB

# %%
df.shape
# Out:
# (5190, 12)

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# visits       0.0
# gender       0.0
# age          0.0
# income       0.0
# illness      0.0
# reduced      0.0
# health       0.0
# private      0.0
# freepoor     0.0
# freerepat    0.0
# nchronic     0.0
# lchronic     0.0
# dtype: float64

# %%
# Data Visualization
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
plt.boxplot(df['health'], vert=False)
plt.ylabel('Variable')
plt.xlabel('health')
plt.title('Box Plot')
plt.show()

# %%
df['health'].value_counts()
# Out:
# health
# 0     3026
# 1      823
# 2      446
# 3      273
# 4      187
# 5      132
# 6      104
# 7       61
# 8       42
# 9       32
# 11      24
# 10      21
# 12      19
# Name: count, dtype: int64

# %%
mean = df['health'].mean()
std = df['health'].std()
print(mean,std)

lower_bound = mean - std * 2
upper_bound = mean + std * 2
print(lower_bound, upper_bound)
# Out:
# 1.217533718689788 2.1242664806617872
# -3.0309992426337864 5.466066680013363

# %%
df2 = df[(df['health']>lower_bound) & (df['health']<upper_bound)]
df2
# Out:
#       visits  gender  age  income  illness  reduced  health private freepoor  \
# 0          1  female   19      55        1        4       1     yes       no
# 1          1  female   19      45        1        2       1     yes       no
# 2          1    male   19      90        3        0       0      no       no
# 3          1    male   19      15        1        0       0      no       no
# 4          1    male   19      45        2        5       1      no       no
# ...      ...     ...  ...     ...      ...      ...     ...     ...      ...
# 5185       0  female   22      55        0        0       0      no       no
# 5186       0    male   27     130        0        0       1      no       no
# 5187       0  female   37      25        1        0       1      no       no
# 5188       0  female   52      65        0        0       0      no       no
# 5189       0    male   72      25        0        0       0      no       no
#
#      freerepat nchronic lchronic
# 0           no       no       no
# 1           no       no       no
# 2           no       no       no
# 3           no       no       no
# 4           no      yes       no
# ...        ...      ...      ...
# 5185        no       no       no
# 5186        no       no       no
# 5187       yes       no       no
# 5188        no       no       no
# 5189       yes       no       no
#
# [4887 rows x 12 columns]

# %%
df2['health'].value_counts()
# Out:
# health
# 0    3026
# 1     823
# 2     446
# 3     273
# 4     187
# 5     132
# Name: count, dtype: int64

# %% [markdown]
# # Check Missing values

# %%
# Checking for missing values
sns.heatmap(df2.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # Gender Distribution

# %%
# viewing gender distribution in our dataset
sns.countplot(x = 'gender',data=df2)
plt.title("Gender Distribution")
plt.show()

# %%
# above, we can notice that we have more females than males in our dataset.
# Now, let's plot a graph with Gender Distribution against age in our dataset.
sns.boxplot(x='gender', y='age',data=df2)
plt.title("Gender Distribution against Age")
plt.show()

# %% [markdown]
# We can see that more than half of our dataset consists of women with wider age distribution, all of which are at a  higher rate than men.

# %% [markdown]
# # Type of Visits

# %%
df2['private'].value_counts()
# Out:
# private
# no     2700
# yes    2187
# Name: count, dtype: int64

# %% [markdown]
# # Finding whether or not 'income' affects the 'visits'

# %%
df2['income'].value_counts()
# Out:
# income
# 25     1104
# 90      567
# 55      440
# 65      431
# 35      428
# 75      426
# 45      378
# 110     347
# 15      233
# 150     209
# 130     152
# 0        71
# 6        70
# 1        31
# Name: count, dtype: int64

# %%
df2['income'].describe()
# Out:
# count    4887.000000
# mean       58.934111
# std        36.953076
# min         0.000000
# 25%        25.000000
# 50%        55.000000
# 75%        90.000000
# max       150.000000
# Name: income, dtype: float64

# %%
# Visualize Minimum, Medium And Maximum income
plt.boxplot(df['income'])
plt.ylabel('Variable')
plt.xlabel('income')
plt.title('Box Plot')
plt.show()

# %% [markdown]
# Above we can see that the Average income value is approximately 60 for the given dataset.

# %%
income = df2['income']
visits = df2['visits']

# %%
# Filter the DataFrame based on income ranges
df_less_than_60 = df2[df2['income'] < 60]
df_greater_than_60 = df2[df2['income'] > 60]

# Plotting the graph
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

# Plot visits when income is less than 60
plt.scatter(df_less_than_60['income'], df_less_than_60['visits'], color='red', label='Income < 60')

# Plot visits when income is greater than 60
plt.scatter(df_greater_than_60['income'], df_greater_than_60['visits'], color='blue', label='Income > 60')

plt.xlabel('Income')
plt.ylabel('Visits')
plt.title('Visits based on Income Ranges')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# From the above graph, we can conclude that the income of a person doesn't influence their no. of visits. Everyone(both rich and poor) have consistent no. of visits.

# %%
df_less_than_60.describe()
# Out:
#             visits          age       income      illness      reduced  \
# count  2755.000000  2755.000000  2755.000000  2755.000000  2755.000000
# mean      0.319419    45.869328    31.846098     1.527768     0.767695
# std       0.814919    22.696803    14.407655     1.408634     2.732263
# min       0.000000    19.000000     0.000000     0.000000     0.000000
# 25%       0.000000    22.000000    25.000000     0.000000     0.000000
# 50%       0.000000    52.000000    25.000000     1.000000     0.000000
# 75%       0.000000    72.000000    45.000000     2.000000     0.000000
# max       8.000000    72.000000    55.000000     5.000000    14.000000
#
#             health
# count  2755.000000
# mean      0.885662
# std       1.344855
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       5.000000

# %%
df_greater_than_60.describe()
# Out:
#             visits          age       income      illness      reduced  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000
# mean      0.212477    33.540338    93.937617     1.130863     0.590525
# std       0.637020    14.521550    26.233696     1.201534     2.231712
# min       0.000000    19.000000    65.000000     0.000000     0.000000
# 25%       0.000000    22.000000    75.000000     0.000000     0.000000
# 50%       0.000000    27.000000    90.000000     1.000000     0.000000
# 75%       0.000000    42.000000   110.000000     2.000000     0.000000
# max       8.000000    72.000000   150.000000     5.000000    14.000000
#
#             health
# count  2132.000000
# mean      0.704503
# std       1.216930
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       5.000000

# %% [markdown]
# # Finding how many people get the Government Insurance

# %%
# Percentage of people getting Government Health Insurance due to low income
parts = ['True','False']
Y = df2[df2['freepoor']=='yes']
N = df2[df2['freepoor']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,3))
plt.pie(x, labels=parts)
plt.title("Percentage of people getting Government Health Insurance due to low income:")
plt.show()

# Percentage of people getting Government Health Insurance due to old age, disability or veteran status
parts = ['True','False']
Y = df2[df2['freerepat']=='yes']
N = df2[df2['freerepat']=='no']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,3))
plt.pie(x, labels=parts)
plt.title("Percentage of people getting Government Health Insurance due to old age, disability or veteran status:")
plt.show()

# %%
len(df2['gender'])
# Out:
# 4887

# %%
df2["gender"] = df2["gender"].map({"male":1,"female":0})
df2
# Out:
# C:\Users\allab\AppData\Local\Temp\ipykernel_24168\377550115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["gender"] = df2["gender"].map({"male":1,"female":0})
#       visits gender  age  income  illness  reduced  health private freepoor  \
# 0          1      0   19      55        1        4       1     yes       no
# 1          1      0   19      45        1        2       1     yes       no
# 2          1      1   19      90        3        0       0      no       no
# 3          1      1   19      15        1        0       0      no       no
# 4          1      1   19      45        2        5       1      no       no
# ...      ...    ...  ...     ...      ...      ...     ...     ...      ...
# 5185       0      0   22      55        0        0       0      no       no
# 5186       0      1   27     130        0        0       1      no       no
# 5187       0      0   37      25        1        0       1      no       no
# 5188       0      0   52      65        0        0       0      no       no
# 5189       0      1   72      25        0        0       0      no       no
#
#      freerepat nchronic lchronic
# 0           no       no       no
# 1           no       no       no
# 2           no       no       no
# 3           no       no       no
# 4           no      yes       no
# ...        ...      ...      ...
# 5185        no       no       no
# 5186        no       no       no
# 5187       yes       no       no
# 5188        no       no       no
# 5189       yes       no       no
#
# [4887 rows x 12 columns]

# %%
df3 = df2.loc[0:,'visits':'health']
df3
# Out:
#       visits gender  age  income  illness  reduced  health
# 0          1      0   19      55        1        4       1
# 1          1      0   19      45        1        2       1
# 2          1      1   19      90        3        0       0
# 3          1      1   19      15        1        0       0
# 4          1      1   19      45        2        5       1
# ...      ...    ...  ...     ...      ...      ...     ...
# 5185       0      0   22      55        0        0       0
# 5186       0      1   27     130        0        0       1
# 5187       0      0   37      25        1        0       1
# 5188       0      0   52      65        0        0       0
# 5189       0      1   72      25        0        0       0
#
# [4887 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x = df3
y = df3.illness

x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.30, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [raw]
# x_train = scaler.fit_transform(x_train)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
mse = cross_val_score(regression, x_train, y_train, scoring = "neg_mean_squared_error", cv = 5)

# %%
np.mean(mse)
# Out:
# -6.834033708810489e-30

# %%
reg_predict = regression.predict(x_test)

# %%
reg_predict
# Out:
# array([1., 3., 1., ..., 1., 2., 1.])

# %%
sns.displot(reg_predict-y_test, kind='kde')

# %%
pip install python-multipart
# Out:
# Requirement already satisfied: python-multipart in c:\users\allab\appdata\local\programs\python\python312\lib\site-packages (0.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\allab\appdata\local\programs\python\python312\lib\site-packages (1.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastapi import FastAPI, File, UploadFile
import json
import nbformat
import nest_asyncio
import uvicorn

# Patch the event loop to avoid the 'asyncio.run()' error in Jupyter
nest_asyncio.apply()

app = FastAPI()

@app.post("/upload/")
async def upload_notebook(file: UploadFile = File(...)):
    # Read the uploaded file
    content = await file.read()
    
    # Decode the content to string (assuming it's a JSON notebook)
    notebook_content = content.decode("utf-8")
    
    # Load the notebook content as JSON
    try:
        notebook_json = nbformat.reads(notebook_content, as_version=4)
        return {"status": "success", "notebook": notebook_json}
    except Exception as e:
        return {"status": "error", "message": str(e)}

# Run the FastAPI app
if __name__ == "__main__":
    uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [24168]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:53488 - "GET / HTTP/1.1" 404 Not Found
